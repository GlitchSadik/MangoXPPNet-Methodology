# %% [markdown]
# # VGG19 Baseline: MangoLeafBD Dataset
# ## Mango Leaf Disease & Pest Classification (Paper-Style Baseline)
#
# **Author**: Md Imdadul Islam
# **Date**: November 2025
# **Model**: VGG19 (Transfer Learning)
# **Dataset**: MangoLeafBD
#
# ---
#
# ### Paper-Style Baseline Settings
# This notebook follows the **MangoLeafXNet paper** baseline methodology:
# - **Input Size**: 227×227 (matching paper)
# - **Preprocessing**: Simple rescale (1/255) + standard augmentations
# - **Optimizer**: SGD with momentum=0.9 (no Nesterov)
# - **Training**: Fixed epochs, no early stopping
# - **Callbacks**: Minimal (checkpoint + CSV logger only)
#
# ---

# %% [markdown]
# ## 1. Setup & Configuration
#
# ### Import Required Libraries

# %%
# Core libraries
import os
import sys
import json
import time
import random
import warnings
from pathlib import Path

# Data manipulation
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

# Deep Learning
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import (
    Input, Dense, Dropout, GlobalAveragePooling2D, Flatten,
    Conv2D, MaxPooling2D, BatchNormalization, Activation
)
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from tensorflow.keras.optimizers import SGD

# Model-specific import
from tensorflow.keras.applications import VGG19

# Metrics
from sklearn.metrics import (
    classification_report, confusion_matrix,
    accuracy_score, precision_recall_fscore_support
)

# Suppress warnings
warnings.filterwarnings('ignore')

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

print("✅ All libraries imported successfully!")
print(f"TensorFlow version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
# Out:
# ✅ All libraries imported successfully!
# TensorFlow version: 2.15.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Set Random Seeds for Reproducibility

# %%
# Set seed for reproducibility
SEED = 42

def set_seed(seed_value=42):
    """Set seed for reproducibility across all libraries"""
    os.environ['PYTHONHASHSEED'] = str(seed_value)
    random.seed(seed_value)
    np.random.seed(seed_value)
    tf.random.set_seed(seed_value)

set_seed(SEED)
print(f"✅ Random seed set to {SEED} for reproducibility")
# Out:
# ✅ Random seed set to 42 for reproducibility

# %% [markdown]
# ### Configure Paths and Dataset

# %%
# ============================================
# PATH CONFIGURATION
# ============================================

from pathlib import Path

# 1) Identify dataset + model for this notebook
DATASET_NAME = 'MangoLeafBD'   # Dataset for this notebook
MODEL_NAME   = 'VGG19'     # Model architecture name

# 2) Project root - MangoXPPNet_Research_Notebook workspace
WORKSPACE_DIR = Path('/Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook')

# 3) Datasets (via symbolic link in workspace)
DATASETS_BASE = WORKSPACE_DIR / 'datasets'
DATA_DIR  = DATASETS_BASE / DATASET_NAME / 'processed'
TRAIN_DIR = DATA_DIR / 'train'
VAL_DIR   = DATA_DIR / 'val'
TEST_DIR  = DATA_DIR / 'test'

# 4) Experiments and outputs save to THIS workspace
EXPERIMENTS_ROOT = WORKSPACE_DIR / DATASET_NAME / 'experiments'
OUTPUTS_ROOT     = WORKSPACE_DIR / DATASET_NAME / 'outputs'

# 5) Helper to create incrementing run directories
def get_next_run_dir(parent_dir, prefix='run_'):
    """Finds the next available run directory (run_1, run_2, ...)"""
    parent_dir = Path(parent_dir)
    parent_dir.mkdir(parents=True, exist_ok=True)
    existing = [d for d in parent_dir.iterdir()
                if d.is_dir() and d.name.startswith(prefix)]
    nums = [int(d.name[len(prefix):]) for d in existing
            if d.name[len(prefix):].isdigit()]
    next_num = max(nums) + 1 if nums else 1
    return parent_dir / f'{prefix}{next_num}'

# 6) Model-aware directory structure
EXPERIMENTS_BASE = EXPERIMENTS_ROOT / MODEL_NAME
OUTPUTS_BASE     = OUTPUTS_ROOT / MODEL_NAME

EXPERIMENT_DIR = get_next_run_dir(EXPERIMENTS_BASE)
OUTPUT_DIR     = get_next_run_dir(OUTPUTS_BASE)

EXPERIMENT_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Display configuration
print("="*60)
print("📁 PATH CONFIGURATION")
print("="*60)
print(f"Workspace      : {WORKSPACE_DIR}")
print(f"Dataset Name   : {DATASET_NAME}")
print(f"Model Name     : {MODEL_NAME}")
print(f"Data Directory : {DATA_DIR}")
print(f"Experiment Dir : {EXPERIMENT_DIR}")
print(f"Output Dir     : {OUTPUT_DIR}")
print("="*60)

# Verify paths exist
for name, path in [('Train', TRAIN_DIR), ('Val', VAL_DIR), ('Test', TEST_DIR)]:
    if path.exists():
        print(f"✅ {name} directory exists")
    else:
        print(f"❌ {name} directory NOT FOUND: {path}")
# Out:
# ============================================================
# 📁 PATH CONFIGURATION
# ============================================================
# Workspace      : /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook
# Dataset Name   : MangoLeafBD
# Model Name     : VGG19
# Data Directory : /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/datasets/MangoLeafBD/processed
# Experiment Dir : /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2
# Output Dir     : /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/outputs/VGG19/run_2
# ============================================================
# ✅ Train directory exists
# ✅ Val directory exists
# ✅ Test directory exists

# %% [markdown]
# ### Paper-Style Hyperparameters

# %%
# ============================================
# PAPER-STYLE HYPERPARAMETERS
# ============================================
# These settings match the MangoLeafXNet paper baselines

IMG_SIZE = 227  # Match MangoLeafXNet paper

# Dataset-specific hyperparameters (from the paper)
if DATASET_NAME in ['MangoLeafBD', 'MangoLeafBD/']:
    EPOCHS = 100
    BATCH_SIZE = 12
    LEARNING_RATE = 0.001
elif DATASET_NAME in ['MangoPest', 'MangoPest/']:
    EPOCHS = 50
    BATCH_SIZE = 12
    LEARNING_RATE = 0.001
elif DATASET_NAME in ['MLDID', 'MLDID/']:
    EPOCHS = 100
    BATCH_SIZE = 16
    LEARNING_RATE = 0.0005
else:
    # Fallback
    EPOCHS = 100
    BATCH_SIZE = 12
    LEARNING_RATE = 0.001

DROPOUT_RATE = 0.3  # Modest dropout for baseline

print("="*60)
print("⚙️  PAPER-STYLE HYPERPARAMETERS")
print("="*60)
print(f"Input Size     : {IMG_SIZE}×{IMG_SIZE} (paper standard)")
print(f"Batch Size     : {BATCH_SIZE}")
print(f"Epochs         : {EPOCHS} (fixed, no early stopping)")
print(f"Learning Rate  : {LEARNING_RATE}")
print(f"Dropout Rate   : {DROPOUT_RATE}")
print(f"Optimizer      : SGD (momentum=0.9)")
print("="*60)
# Out:
# ============================================================
# ⚙️  PAPER-STYLE HYPERPARAMETERS
# ============================================================
# Input Size     : 227×227 (paper standard)
# Batch Size     : 12
# Epochs         : 100 (fixed, no early stopping)
# Learning Rate  : 0.001
# Dropout Rate   : 0.3
# Optimizer      : SGD (momentum=0.9)
# ============================================================

# %% [markdown]
# ## 2. Data Loading & Preprocessing
#
# ### Simple Paper-Style Data Generators

# %%
# ============================================
# PAPER-STYLE DATA GENERATORS
# ============================================
# Simple rescale + standard augmentations (same for all models)

# Training: rescale + augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    brightness_range=(0.8, 1.2),
    horizontal_flip=True,
    fill_mode='nearest'
)

# Validation & Test: rescale only (NO augmentation)
val_test_datagen = ImageDataGenerator(
    rescale=1.0/255.0
)

# Create generators
train_generator = train_datagen.flow_from_directory(
    str(TRAIN_DIR),
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=SEED
)

val_generator = val_test_datagen.flow_from_directory(
    str(VAL_DIR),
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=SEED
)

test_generator = val_test_datagen.flow_from_directory(
    str(TEST_DIR),
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Get number of classes and class names
n_classes = len(train_generator.class_indices)
idx2name = [None] * n_classes
for name, idx in train_generator.class_indices.items():
    idx2name[idx] = name

print("\n" + "="*60)
print("📚 DATA GENERATORS CREATED (Paper-Style)")
print("="*60)
print(f"Preprocessing  : rescale=1/255 (same for all models)")
print(f"Augmentation   : rotation, shift, zoom, flip, brightness")
print(f"Number of Classes: {n_classes}")
print(f"Class Order: {idx2name}")
print(f"Training samples  : {train_generator.samples}")
print(f"Validation samples: {val_generator.samples}")
print(f"Test samples      : {test_generator.samples}")
print("="*60)

# Save classes.json
with open(EXPERIMENT_DIR / 'classes.json', 'w') as f:
    json.dump(idx2name, f, indent=2)

print(f"\n✅ Class order saved to: {EXPERIMENT_DIR / 'classes.json'}")
# Out:
# Found 3200 images belonging to 8 classes.
# Found 400 images belonging to 8 classes.
# Found 400 images belonging to 8 classes.
#
# ============================================================
# 📚 DATA GENERATORS CREATED (Paper-Style)
# ============================================================
# Preprocessing  : rescale=1/255 (same for all models)
# Augmentation   : rotation, shift, zoom, flip, brightness
# Number of Classes: 8
# Class Order: ['Anthracnose', 'Bacterial Canker', 'Cutting Weevil', 'Die Back', 'Gall Midge', 'Healthy', 'Powdery Mildew', 'Sooty Mould']
# Training samples  : 3200
# Validation samples: 400
# Test samples      : 400
# ============================================================
#
# ✅ Class order saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/classes.json

# %% [markdown]
# ## 3. Model Architecture
#
# ### Build VGG19 Baseline Model

# %%
# ============================================
# VGG19 BASELINE MODEL (Transfer Learning)
# ============================================
# Paper-style: frozen base + simple classification head

print("\n" + "="*60)
print(f"🏗️  BUILDING {MODEL_NAME} BASELINE MODEL (Paper-style)")
print("="*60)

# 1) Load base model with ImageNet weights
base_model = VGG19(weights="imagenet", include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))

# 2) Freeze ALL base layers (no fine-tuning for baseline)
base_model.trainable = False

print(f"✅ Base model loaded with ImageNet weights")
print(f"   • Base model layers frozen: {len(base_model.layers)} layers")

# 3) Simple classification head (paper-style)
inputs = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D(name='gap')(x)
x = Dense(512, activation='relu', name='fc1')(x)
x = Dropout(DROPOUT_RATE, name='dropout')(x)
outputs = Dense(n_classes, activation='softmax', name='output')(x)

# 4) Create model
model = Model(inputs, outputs, name=f'{MODEL_NAME}_baseline')

print(f"\n✅ Baseline model built successfully!")
print(f"   • Model: {MODEL_NAME}")
print(f"   • Input Shape: {IMG_SIZE}×{IMG_SIZE}×3")
print(f"   • Number of Classes: {n_classes}")
print(f"   • Head: GAP → Dense(512) → Dropout({DROPOUT_RATE}) → Output")

model.summary()
# Out:
# ============================================================
# 🏗️  BUILDING VGG19 BASELINE MODEL (Paper-style)
# ============================================================
# 2025-11-27 06:05:37.170461: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2025-11-27 06:05:37.170495: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-11-27 06:05:37.170504: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.92 GB
# 2025-11-27 06:05:37.170538: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-11-27 06:05:37.170552: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ✅ Base model loaded with ImageNet weights
#    • Base model layers frozen: 22 layers
#
# ✅ Baseline model built successfully!
#    • Model: VGG19
#    • Input Shape: 227×227×3
#    • Number of Classes: 8
#    • Head: GAP → Dense(512) → Dropout(0.3) → Output
# Model: "VGG19_baseline"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  gap (GlobalAveragePooling2  (None, 512)               0
#  D)
#
#  fc1 (Dense)                 (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  output (Dense)              (None, 8)                 4104
#
# =================================================================
# Total params: 20291144 (77.40 MB)
# Trainable params: 266760 (1.02 MB)
# Non-trainable params: 20024384 (76.39 MB)
# _________________________________________________________________

# %% [markdown]
# ## 4. Model Training
#
# ### Compile and Train (Paper-Style)

# %%
# ============================================
# COMPILE MODEL (Paper-Style)
# ============================================
# SGD with momentum=0.9, no Nesterov (matching paper)

optimizer = SGD(learning_rate=LEARNING_RATE, momentum=0.9, nesterov=False)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("✅ Model compiled (Paper-style)")
print(f"   • Optimizer: SGD (momentum=0.9, no Nesterov)")
print(f"   • Learning Rate: {LEARNING_RATE} (fixed)")
print(f"   • Loss: Categorical Crossentropy")
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# ✅ Model compiled (Paper-style)
#    • Optimizer: SGD (momentum=0.9, no Nesterov)
#    • Learning Rate: 0.001 (fixed)
#    • Loss: Categorical Crossentropy

# %%
# ============================================
# MINIMAL CALLBACKS (Paper-Style)
# ============================================
# No EarlyStopping, no ReduceLROnPlateau
# Just checkpoint best model and log training

model_filename = f"{MODEL_NAME}_{DATASET_NAME}_best.h5"
model_path = EXPERIMENT_DIR / model_filename
csv_log_path = EXPERIMENT_DIR / 'training_log.csv'

callbacks = [
    ModelCheckpoint(
        filepath=str(model_path),
        monitor='val_accuracy',
        mode='max',
        save_best_only=True,
        save_weights_only=False,
        verbose=1
    ),
    CSVLogger(
        filename=str(csv_log_path),
        append=False
    )
]

print("="*60)
print("🔧 MINIMAL CALLBACKS (Paper-Style)")
print("="*60)
print(f"ModelCheckpoint: Save best model to {model_filename}")
print(f"CSVLogger: Log to {csv_log_path.name}")
print("NO EarlyStopping (train for full {EPOCHS} epochs)")
print("NO ReduceLROnPlateau (fixed learning rate)")
print("="*60)

# Save model info
total_params = model.count_params()
trainable_params = sum([tf.size(w).numpy() for w in model.trainable_weights])

model_info = {
    'dataset': DATASET_NAME,
    'model_name': MODEL_NAME,
    'architecture': 'Transfer Learning Baseline',
    'paper_style': True,
    'input_shape': [IMG_SIZE, IMG_SIZE, 3],
    'num_classes': n_classes,
    'total_params': int(total_params),
    'trainable_params': int(trainable_params),
    'batch_size': BATCH_SIZE,
    'epochs': EPOCHS,
    'learning_rate': LEARNING_RATE,
    'optimizer': 'SGD (momentum=0.9)',
    'model_path': str(model_path)
}

with open(EXPERIMENT_DIR / 'model_info.json', 'w') as f:
    json.dump(model_info, f, indent=2)

print(f"\n✅ Model info saved to: {EXPERIMENT_DIR / 'model_info.json'}")
# Out:
# ============================================================
# 🔧 MINIMAL CALLBACKS (Paper-Style)
# ============================================================
# ModelCheckpoint: Save best model to VGG19_MangoLeafBD_best.h5
# CSVLogger: Log to training_log.csv
# NO EarlyStopping (train for full {EPOCHS} epochs)
# NO ReduceLROnPlateau (fixed learning rate)
# ============================================================
#
# ✅ Model info saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/model_info.json

# %%
# ============================================
# TRAINING (Paper-Style: Fixed Epochs)
# ============================================

print("\n" + "="*80)
print("🚀 STARTING TRAINING (Paper-Style Baseline)")
print("="*80)
print(f"Model: {MODEL_NAME}")
print(f"Dataset: {DATASET_NAME}")
print(f"Epochs: {EPOCHS} (fixed, no early stopping)")
print(f"Batch Size: {BATCH_SIZE}")
print(f"Learning Rate: {LEARNING_RATE} (fixed, no decay)")
print("="*80 + "\n")

start_time = time.time()

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

end_time = time.time()
training_time = end_time - start_time

print("\n" + "="*80)
print("✅ TRAINING COMPLETED")
print("="*80)
print(f"Total training time: {training_time/60:.2f} minutes")
print(f"Best model saved to: {model_path}")
print("="*80)

# Save training history
history_dict = {k: [float(x) for x in v] for k, v in history.history.items()}
with open(EXPERIMENT_DIR / 'history.json', 'w') as f:
    json.dump(history_dict, f, indent=2)

print(f"\n✅ Training history saved to: {EXPERIMENT_DIR / 'history.json'}")
# Out:
# ================================================================================
# 🚀 STARTING TRAINING (Paper-Style Baseline)
# ================================================================================
# Model: VGG19
# Dataset: MangoLeafBD
# Epochs: 100 (fixed, no early stopping)
# Batch Size: 12
# Learning Rate: 0.001 (fixed, no decay)
# ================================================================================
#
# Epoch 1/100
# 2025-11-27 06:05:43.058051: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 2025-11-27 06:05:43.073227: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node SGD/AssignVariableOp.
# 267/267 [==============================] - ETA: 0s - loss: 2.0112 - accuracy: 0.2400
# Epoch 1: val_accuracy improved from -inf to 0.39500, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 116s 433ms/step - loss: 2.0112 - accuracy: 0.2400 - val_loss: 1.8020 - val_accuracy: 0.3950
# Epoch 2/100
# 267/267 [==============================] - ETA: 0s - loss: 1.6503 - accuracy: 0.4647
# Epoch 2: val_accuracy improved from 0.39500 to 0.44750, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 119s 445ms/step - loss: 1.6503 - accuracy: 0.4647 - val_loss: 1.6361 - val_accuracy: 0.4475
# Epoch 3/100
# 267/267 [==============================] - ETA: 0s - loss: 1.4058 - accuracy: 0.5672
# Epoch 3: val_accuracy improved from 0.44750 to 0.61500, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 118s 441ms/step - loss: 1.4058 - accuracy: 0.5672 - val_loss: 1.3143 - val_accuracy: 0.6150
# Epoch 4/100
# 267/267 [==============================] - ETA: 0s - loss: 1.2157 - accuracy: 0.6347
# Epoch 4: val_accuracy improved from 0.61500 to 0.62000, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 121s 452ms/step - loss: 1.2157 - accuracy: 0.6347 - val_loss: 1.1906 - val_accuracy: 0.6200
# Epoch 5/100
# 267/267 [==============================] - ETA: 0s - loss: 1.0839 - accuracy: 0.6781
# Epoch 5: val_accuracy did not improve from 0.62000
# 267/267 [==============================] - 119s 447ms/step - loss: 1.0839 - accuracy: 0.6781 - val_loss: 1.1258 - val_accuracy: 0.6175
# Epoch 6/100
# 267/267 [==============================] - ETA: 0s - loss: 0.9721 - accuracy: 0.7344
# Epoch 6: val_accuracy improved from 0.62000 to 0.74500, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 118s 442ms/step - loss: 0.9721 - accuracy: 0.7344 - val_loss: 0.9606 - val_accuracy: 0.7450
# Epoch 7/100
# 267/267 [==============================] - ETA: 0s - loss: 0.8700 - accuracy: 0.7572
# Epoch 7: val_accuracy improved from 0.74500 to 0.83750, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] -
saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 120s 449ms/step - loss: 0.3368 - accuracy: 0.8884 - val_loss: 0.2955 - val_accuracy: 0.9275
# Epoch 31/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3356 - accuracy: 0.8856
# Epoch 31: val_accuracy did not improve from 0.92750
# 267/267 [==============================] - 118s 440ms/step - loss: 0.3356 - accuracy: 0.8856 - val_loss: 0.3407 - val_accuracy: 0.9025
# Epoch 32/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3376 - accuracy: 0.8891
# Epoch 32: val_accuracy improved from 0.92750 to 0.93500, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 118s 442ms/step - loss: 0.3376 - accuracy: 0.8891 - val_loss: 0.2791 - val_accuracy: 0.9350
# Epoch 33/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3268 - accuracy: 0.8934
# Epoch 33: val_accuracy did not improve from 0.93500
# 267/267 [==============================] - 119s 446ms/step - loss: 0.3268 - accuracy: 0.8934 - val_loss: 0.3255 - val_accuracy: 0.8800
# Epoch 34/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3208 - accuracy: 0.8991
# Epoch 34: val_accuracy did not improve from 0.93500
# 267/267 [==============================] - 119s 447ms/step - loss: 0.3208 - accuracy: 0.8991 - val_loss: 0.2616 - val_accuracy: 0.9350
# Epoch 35/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3058 - accuracy: 0.9062
# Epoch 35: val_accuracy did not improve from 0.93500
# 267/267 [==============================] - 118s 443ms/step - loss: 0.3058 - accuracy: 0.9062 - val_loss: 0.2681 - val_accuracy: 0.9300
# Epoch 36/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3025 - accuracy: 0.9047
# Epoch 36: val_accuracy did not improve from 0.93500
# 267/267 [==============================] - 118s 444ms/step - loss: 0.3025 - accuracy: 0.9047 - val_loss: 0.3313 - val_accuracy: 0.9000
# Epoch 37/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3107 - accuracy: 0.8928
# Epoch 37: val_accuracy improved from 0.93500 to 0.94000, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 119s 446ms/step - loss: 0.3107 - accuracy: 0.8928 - val_loss: 0.2521 - val_accuracy: 0.9400
# Epoch 38/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3147 - accuracy: 0.8963
# Epoch 38: val_accuracy improved from 0.94000 to 0.94250, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 121s 453ms/step - loss: 0.3147 - accuracy: 0.8963 - val_loss: 0.2403 - val_accuracy: 0.9425
# Epoch 39/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.9053
# Epoch 39: val_accuracy did not improve from 0.94250
# 267/267 [==============================] - 121s 452ms/step - loss: 0.2960 - accuracy: 0.9053 - val_loss: 0.2867 - val_accuracy: 0.9000
# Epoch 40/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2953 - accuracy: 0.8994
# Epoch 40: val_accuracy did not improve from 0.94250
# 267/267 [==============================] - 120s 451ms/step - loss: 0.2953 - accuracy: 0.8994 - val_loss: 0.2478 - val_accuracy: 0.9350
# Epoch 41/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2939 - accuracy: 0.9031
# Epoch 41: val_accuracy did not improve from 0.94250
# 267/267 [==============================] - 122s 456ms/step - loss: 0.2939 - accuracy: 0.9031 - val_loss: 0.2825 - val_accuracy: 0.9175
# Epoch 42/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2784 - accuracy: 0.9041
# Epoch 42: val_accuracy improved from 0.94250 to 0.94750, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 122s 456ms/step - loss: 0.2784 - accuracy: 0.9041 - val_loss: 0.2237 - val_accuracy: 0.9475
# Epoch 43/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2852 - accuracy: 0.9013
# Epoch 43: val_accuracy did not improve from 0.94750
# 267/267 [==============================] - 122s 458ms/step - loss: 0.2852 - accuracy: 0.9013 - val_loss: 0.2877 - val_accuracy: 0.9025
# Epoch 44/100
# 267/267 [==============================] - ETA: 0s - loss: 0.
100
# 267/267 [==============================] - ETA: 0s - loss: 0.2110 - accuracy: 0.9262
# Epoch 76: val_accuracy did not improve from 0.95750
# 267/267 [==============================] - 84s 314ms/step - loss: 0.2110 - accuracy: 0.9262 - val_loss: 0.1545 - val_accuracy: 0.9575
# Epoch 77/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.9197
# Epoch 77: val_accuracy did not improve from 0.95750
# 267/267 [==============================] - 79s 294ms/step - loss: 0.2228 - accuracy: 0.9197 - val_loss: 0.1815 - val_accuracy: 0.9475
# Epoch 78/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1901 - accuracy: 0.9353
# Epoch 78: val_accuracy did not improve from 0.95750
# 267/267 [==============================] - 45s 169ms/step - loss: 0.1901 - accuracy: 0.9353 - val_loss: 0.1603 - val_accuracy: 0.9525
# Epoch 79/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9287
# Epoch 79: val_accuracy did not improve from 0.95750
# 267/267 [==============================] - 45s 169ms/step - loss: 0.2080 - accuracy: 0.9287 - val_loss: 0.1614 - val_accuracy: 0.9550
# Epoch 80/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1872 - accuracy: 0.9334
# Epoch 80: val_accuracy did not improve from 0.95750
# 267/267 [==============================] - 45s 169ms/step - loss: 0.1872 - accuracy: 0.9334 - val_loss: 0.1611 - val_accuracy: 0.9550
# Epoch 81/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9334
# Epoch 81: val_accuracy did not improve from 0.95750
# 267/267 [==============================] - 45s 169ms/step - loss: 0.2086 - accuracy: 0.9334 - val_loss: 0.1674 - val_accuracy: 0.9425
# Epoch 82/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2251 - accuracy: 0.9153
# Epoch 82: val_accuracy did not improve from 0.95750
# 267/267 [==============================] - 45s 169ms/step - loss: 0.2251 - accuracy: 0.9153 - val_loss: 0.2682 - val_accuracy: 0.9075
# Epoch 83/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.9334
# Epoch 83: val_accuracy improved from 0.95750 to 0.96250, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 45s 170ms/step - loss: 0.1894 - accuracy: 0.9334 - val_loss: 0.1474 - val_accuracy: 0.9625
# Epoch 84/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2003 - accuracy: 0.9325
# Epoch 84: val_accuracy did not improve from 0.96250
# 267/267 [==============================] - 45s 169ms/step - loss: 0.2003 - accuracy: 0.9325 - val_loss: 0.1908 - val_accuracy: 0.9250
# Epoch 85/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2048 - accuracy: 0.9303
# Epoch 85: val_accuracy did not improve from 0.96250
# 267/267 [==============================] - 45s 168ms/step - loss: 0.2048 - accuracy: 0.9303 - val_loss: 0.1754 - val_accuracy: 0.9450
# Epoch 86/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1944 - accuracy: 0.9322
# Epoch 86: val_accuracy did not improve from 0.96250
# 267/267 [==============================] - 45s 169ms/step - loss: 0.1944 - accuracy: 0.9322 - val_loss: 0.1377 - val_accuracy: 0.9625
# Epoch 87/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9328
# Epoch 87: val_accuracy did not improve from 0.96250
# 267/267 [==============================] - 45s 168ms/step - loss: 0.1988 - accuracy: 0.9328 - val_loss: 0.1633 - val_accuracy: 0.9425
# Epoch 88/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1918 - accuracy: 0.9356
# Epoch 88: val_accuracy improved from 0.96250 to 0.96500, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# 267/267 [==============================] - 45s 169ms/step - loss: 0.1918 - accuracy: 0.9356 - val_loss: 0.1365 - val_accuracy: 0.9650
# Epoch 89/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1893 - accuracy: 0.9337
# Epoch 89: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 45s 168ms/step - loss: 0.1893 - accuracy: 0.9337 - val_loss: 0.1686 - val_accuracy: 0.9525
# Epoch 90/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2048 - accuracy: 0.9275
# Epoch 90: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 45s 168ms/step - loss: 0.2048 - accuracy: 0.9275 - val_loss: 0.2076 - val_accuracy: 0.9150
# Epoch 91/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9359
# Epoch 91: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 45s 168ms/step - loss: 0.1841 - accuracy: 0.9359 - val_loss: 0.1461 - val_accuracy: 0.9575
# Epoch 92/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1899 - accuracy: 0.9322
# Epoch 92: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 40s 151ms/step - loss: 0.1899 - accuracy: 0.9322 - val_loss: 0.1528 - val_accuracy: 0.9650
# Epoch 93/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1909 - accuracy: 0.9381
# Epoch 93: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 36s 137ms/step - loss: 0.1909 - accuracy: 0.9381 - val_loss: 0.1623 - val_accuracy: 0.9475
# Epoch 94/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1776 - accuracy: 0.9381
# Epoch 94: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 36s 136ms/step - loss: 0.1776 - accuracy: 0.9381 - val_loss: 0.1614 - val_accuracy: 0.9425
# Epoch 95/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9337
# Epoch 95: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 36s 136ms/step - loss: 0.1877 - accuracy: 0.9337 - val_loss: 0.1388 - val_accuracy: 0.9625
# Epoch 96/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2018 - accuracy: 0.9328
# Epoch 96: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 36s 137ms/step - loss: 0.2018 - accuracy: 0.9328 - val_loss: 0.1768 - val_accuracy: 0.9475
# Epoch 97/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9366
# Epoch 97: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 36s 137ms/step - loss: 0.1928 - accuracy: 0.9366 - val_loss: 0.1964 - val_accuracy: 0.9275
# Epoch 98/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2063 - accuracy: 0.9241
# Epoch 98: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 36s 136ms/step - loss: 0.2063 - accuracy: 0.9241 - val_loss: 0.2399 - val_accuracy: 0.9050
# Epoch 99/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2001 - accuracy: 0.9247
# Epoch 99: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 36s 136ms/step - loss: 0.2001 - accuracy: 0.9247 - val_loss: 0.1842 - val_accuracy: 0.9350
# Epoch 100/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1808 - accuracy: 0.9397
# Epoch 100: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 36s 136ms/step - loss: 0.1808 - accuracy: 0.9397 - val_loss: 0.1436 - val_accuracy: 0.9575
#
# ================================================================================
# ✅ TRAINING COMPLETED
# ================================================================================
# Total training time: 160.95 minutes
# Best model saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# ================================================================================
#
# ✅ Training history saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/history.json

# %% [markdown]
# ## 5. Model Evaluation
#
# ### Load Best Model and Generate Predictions

# %%
# ============================================
# MODEL EVALUATION
# ============================================

print("="*60)
print("📥 LOADING BEST MODEL FOR EVALUATION")
print("="*60)
print(f"Model path: {model_path}")

best_model = load_model(str(model_path))
print("✅ Best model loaded successfully!")

# Make predictions
print("\n🔮 Making predictions on test set...")
y_pred_probs = best_model.predict(test_generator, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes

# Calculate metrics
overall_accuracy = accuracy_score(y_true, y_pred)
macro_precision, macro_recall, macro_f1, _ = precision_recall_fscore_support(
    y_true, y_pred, average='macro'
)
weighted_precision, weighted_recall, weighted_f1, _ = precision_recall_fscore_support(
    y_true, y_pred, average='weighted'
)

# Classification report
report = classification_report(
    y_true, y_pred,
    target_names=idx2name,
    digits=4
)

print("\n" + "="*80)
print("📊 EVALUATION RESULTS")
print("="*80)
print(f"Overall Accuracy: {overall_accuracy:.4f} ({overall_accuracy*100:.2f}%)")
print(f"Macro Precision : {macro_precision:.4f}")
print(f"Macro Recall    : {macro_recall:.4f}")
print(f"Macro F1-Score  : {macro_f1:.4f}")
print("="*80)
print("\n" + report)

# Save classification report
with open(OUTPUT_DIR / 'classification_report.txt', 'w') as f:
    f.write(f"{MODEL_NAME} on {DATASET_NAME} - Classification Report\n")
    f.write("="*80 + "\n\n")
    f.write(report)

# Save metrics CSV
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, labels=range(n_classes)
)
metrics_df = pd.DataFrame({
    'Class': idx2name,
    'Precision': precision,
    'Recall': recall,
    'F1-Score': f1,
    'Support': support
})
metrics_df.to_csv(OUTPUT_DIR / 'per_class_metrics.csv', index=False)

# Save evaluation summary
summary = f"""{'='*80}
{MODEL_NAME} on {DATASET_NAME} - Evaluation Summary (Paper-Style Baseline)
{'='*80}

Model: {MODEL_NAME}
Dataset: {DATASET_NAME}
Test Accuracy: {overall_accuracy:.4f} ({overall_accuracy*100:.2f}%)
Macro Avg - P: {macro_precision:.4f}, R: {macro_recall:.4f}, F1: {macro_f1:.4f}
Weighted Avg - P: {weighted_precision:.4f}, R: {weighted_recall:.4f}, F1: {weighted_f1:.4f}

Training Settings:
- Input Size: {IMG_SIZE}×{IMG_SIZE}
- Epochs: {EPOCHS} (fixed)
- Batch Size: {BATCH_SIZE}
- Learning Rate: {LEARNING_RATE}
- Optimizer: SGD (momentum=0.9)
{'='*80}
"""

with open(OUTPUT_DIR / 'evaluation_summary.txt', 'w') as f:
    f.write(summary)

print(f"\n✅ Results saved to: {OUTPUT_DIR}")
# Out:
# ============================================================
# 📥 LOADING BEST MODEL FOR EVALUATION
# ============================================================
# Model path: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG19/run_2/VGG19_MangoLeafBD_best.h5
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# ✅ Best model loaded successfully!
#
# 🔮 Making predictions on test set...
# 34/34 [==============================] - 4s 119ms/step
#
# ================================================================================
# 📊 EVALUATION RESULTS
# ================================================================================
# Overall Accuracy: 0.9550 (95.50%)
# Macro Precision : 0.9564
# Macro Recall    : 0.9550
# Macro F1-Score  : 0.9552
# ================================================================================
#
#                   precision    recall  f1-score   support
#
#      Anthracnose     0.8727    0.9600    0.9143        50
# Bacterial Canker     0.9583    0.9200    0.9388        50
#   Cutting Weevil     1.0000    0.9800    0.9899        50
#         Die Back     0.9608    0.9800    0.9703        50
#       Gall Midge     0.9583    0.9200    0.9388        50
#          Healthy     0.9792    0.9400    0.9592        50
#   Powdery Mildew     0.9796    0.9600    0.9697        50
#      Sooty Mould     0.9423    0.9800    0.9608        50
#
#         accuracy                         0.9550       400
#        macro avg     0.9564    0.9550    0.9552       400
#     weighted avg     0.9564    0.9550    0.9552       400
#
#
# ✅ Results saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/outputs/VGG19/run_2

# %%
# ============================================
# VISUALIZATIONS
# ============================================

# 1) Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=idx2name,
            yticklabels=idx2name,
            cbar_kws={'label': 'Count'})
plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')
plt.ylabel('True Label', fontsize=12, fontweight='bold')
plt.title(f'Confusion Matrix - {MODEL_NAME} on {DATASET_NAME} (Paper-Style Baseline)',
         fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"✅ Confusion matrix saved to: {OUTPUT_DIR / 'confusion_matrix.png'}")

# 2) Training History
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Loss plot
axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
axes[0].set_title('Model Loss During Training', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy plot
axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
axes[1].set_title('Model Accuracy During Training', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'training_history.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"✅ Training history plot saved to: {OUTPUT_DIR / 'training_history.png'}")
# Out:
# ✅ Confusion matrix saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/outputs/VGG19/run_2/confusion_matrix.png
# ✅ Training history plot saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/outputs/VGG19/run_2/training_history.png
