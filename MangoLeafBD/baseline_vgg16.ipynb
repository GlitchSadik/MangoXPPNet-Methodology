# %% [markdown]
# # VGG16 Baseline: MangoLeafBD Dataset
# ## Mango Leaf Disease & Pest Classification (Paper-Style Baseline)
#
# **Author**: Md Imdadul Islam
# **Date**: November 2025
# **Model**: VGG16 (Transfer Learning)
# **Dataset**: MangoLeafBD
#
# ---
#
# ### Paper-Style Baseline Settings
# This notebook follows the **MangoLeafXNet paper** baseline methodology:
# - **Input Size**: 227×227 (matching paper)
# - **Preprocessing**: Simple rescale (1/255) + standard augmentations
# - **Optimizer**: SGD with momentum=0.9 (no Nesterov)
# - **Training**: Fixed epochs, no early stopping
# - **Callbacks**: Minimal (checkpoint + CSV logger only)
#
# ---

# %% [markdown]
# ## 1. Setup & Configuration
#
# ### Import Required Libraries

# %%
# Core libraries
import os
import sys
import json
import time
import random
import warnings
from pathlib import Path

# Data manipulation
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

# Deep Learning
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import (
    Input, Dense, Dropout, GlobalAveragePooling2D, Flatten,
    Conv2D, MaxPooling2D, BatchNormalization, Activation
)
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from tensorflow.keras.optimizers import SGD

# Model-specific import
from tensorflow.keras.applications import VGG16

# Metrics
from sklearn.metrics import (
    classification_report, confusion_matrix,
    accuracy_score, precision_recall_fscore_support
)

# Suppress warnings
warnings.filterwarnings('ignore')

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

print("✅ All libraries imported successfully!")
print(f"TensorFlow version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
# Out:
# ✅ All libraries imported successfully!
# TensorFlow version: 2.15.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Set Random Seeds for Reproducibility

# %%
# Set seed for reproducibility
SEED = 42

def set_seed(seed_value=42):
    """Set seed for reproducibility across all libraries"""
    os.environ['PYTHONHASHSEED'] = str(seed_value)
    random.seed(seed_value)
    np.random.seed(seed_value)
    tf.random.set_seed(seed_value)

set_seed(SEED)
print(f"✅ Random seed set to {SEED} for reproducibility")
# Out:
# ✅ Random seed set to 42 for reproducibility

# %% [markdown]
# ### Configure Paths and Dataset

# %%
# ============================================
# PATH CONFIGURATION
# ============================================

from pathlib import Path

# 1) Identify dataset + model for this notebook
DATASET_NAME = 'MangoLeafBD'   # Dataset for this notebook
MODEL_NAME   = 'VGG16'     # Model architecture name

# 2) Project root - MangoXPPNet_Research_Notebook workspace
WORKSPACE_DIR = Path('/Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook')

# 3) Datasets (via symbolic link in workspace)
DATASETS_BASE = WORKSPACE_DIR / 'datasets'
DATA_DIR  = DATASETS_BASE / DATASET_NAME / 'processed'
TRAIN_DIR = DATA_DIR / 'train'
VAL_DIR   = DATA_DIR / 'val'
TEST_DIR  = DATA_DIR / 'test'

# 4) Experiments and outputs save to THIS workspace
EXPERIMENTS_ROOT = WORKSPACE_DIR / DATASET_NAME / 'experiments'
OUTPUTS_ROOT     = WORKSPACE_DIR / DATASET_NAME / 'outputs'

# 5) Helper to create incrementing run directories
def get_next_run_dir(parent_dir, prefix='run_'):
    """Finds the next available run directory (run_1, run_2, ...)"""
    parent_dir = Path(parent_dir)
    parent_dir.mkdir(parents=True, exist_ok=True)
    existing = [d for d in parent_dir.iterdir()
                if d.is_dir() and d.name.startswith(prefix)]
    nums = [int(d.name[len(prefix):]) for d in existing
            if d.name[len(prefix):].isdigit()]
    next_num = max(nums) + 1 if nums else 1
    return parent_dir / f'{prefix}{next_num}'

# 6) Model-aware directory structure
EXPERIMENTS_BASE = EXPERIMENTS_ROOT / MODEL_NAME
OUTPUTS_BASE     = OUTPUTS_ROOT / MODEL_NAME

EXPERIMENT_DIR = get_next_run_dir(EXPERIMENTS_BASE)
OUTPUT_DIR     = get_next_run_dir(OUTPUTS_BASE)

EXPERIMENT_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Display configuration
print("="*60)
print("📁 PATH CONFIGURATION")
print("="*60)
print(f"Workspace      : {WORKSPACE_DIR}")
print(f"Dataset Name   : {DATASET_NAME}")
print(f"Model Name     : {MODEL_NAME}")
print(f"Data Directory : {DATA_DIR}")
print(f"Experiment Dir : {EXPERIMENT_DIR}")
print(f"Output Dir     : {OUTPUT_DIR}")
print("="*60)

# Verify paths exist
for name, path in [('Train', TRAIN_DIR), ('Val', VAL_DIR), ('Test', TEST_DIR)]:
    if path.exists():
        print(f"✅ {name} directory exists")
    else:
        print(f"❌ {name} directory NOT FOUND: {path}")
# Out:
# ============================================================
# 📁 PATH CONFIGURATION
# ============================================================
# Workspace      : /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook
# Dataset Name   : MangoLeafBD
# Model Name     : VGG16
# Data Directory : /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/datasets/MangoLeafBD/processed
# Experiment Dir : /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3
# Output Dir     : /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/outputs/VGG16/run_3
# ============================================================
# ✅ Train directory exists
# ✅ Val directory exists
# ✅ Test directory exists

# %% [markdown]
# ### Paper-Style Hyperparameters

# %%
# ============================================
# PAPER-STYLE HYPERPARAMETERS
# ============================================
# These settings match the MangoLeafXNet paper baselines

IMG_SIZE = 227  # Match MangoLeafXNet paper

# Dataset-specific hyperparameters (from the paper)
if DATASET_NAME in ['MangoLeafBD', 'MangoLeafBD/']:
    EPOCHS = 100
    BATCH_SIZE = 12
    LEARNING_RATE = 0.001
elif DATASET_NAME in ['MangoPest', 'MangoPest/']:
    EPOCHS = 50
    BATCH_SIZE = 12
    LEARNING_RATE = 0.001
elif DATASET_NAME in ['MLDID', 'MLDID/']:
    EPOCHS = 100
    BATCH_SIZE = 16
    LEARNING_RATE = 0.0005
else:
    # Fallback
    EPOCHS = 100
    BATCH_SIZE = 12
    LEARNING_RATE = 0.001

DROPOUT_RATE = 0.3  # Modest dropout for baseline

print("="*60)
print("⚙️  PAPER-STYLE HYPERPARAMETERS")
print("="*60)
print(f"Input Size     : {IMG_SIZE}×{IMG_SIZE} (paper standard)")
print(f"Batch Size     : {BATCH_SIZE}")
print(f"Epochs         : {EPOCHS} (fixed, no early stopping)")
print(f"Learning Rate  : {LEARNING_RATE}")
print(f"Dropout Rate   : {DROPOUT_RATE}")
print(f"Optimizer      : SGD (momentum=0.9)")
print("="*60)
# Out:
# ============================================================
# ⚙️  PAPER-STYLE HYPERPARAMETERS
# ============================================================
# Input Size     : 227×227 (paper standard)
# Batch Size     : 12
# Epochs         : 100 (fixed, no early stopping)
# Learning Rate  : 0.001
# Dropout Rate   : 0.3
# Optimizer      : SGD (momentum=0.9)
# ============================================================

# %% [markdown]
# ## 2. Data Loading & Preprocessing
#
# ### Simple Paper-Style Data Generators

# %%
# ============================================
# PAPER-STYLE DATA GENERATORS
# ============================================
# Simple rescale + standard augmentations (same for all models)

# Training: rescale + augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    brightness_range=(0.8, 1.2),
    horizontal_flip=True,
    fill_mode='nearest'
)

# Validation & Test: rescale only (NO augmentation)
val_test_datagen = ImageDataGenerator(
    rescale=1.0/255.0
)

# Create generators
train_generator = train_datagen.flow_from_directory(
    str(TRAIN_DIR),
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=SEED
)

val_generator = val_test_datagen.flow_from_directory(
    str(VAL_DIR),
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=SEED
)

test_generator = val_test_datagen.flow_from_directory(
    str(TEST_DIR),
    target_size=(IMG_SIZE, IMG_SIZE),
    color_mode='rgb',
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

# Get number of classes and class names
n_classes = len(train_generator.class_indices)
idx2name = [None] * n_classes
for name, idx in train_generator.class_indices.items():
    idx2name[idx] = name

print("\n" + "="*60)
print("📚 DATA GENERATORS CREATED (Paper-Style)")
print("="*60)
print(f"Preprocessing  : rescale=1/255 (same for all models)")
print(f"Augmentation   : rotation, shift, zoom, flip, brightness")
print(f"Number of Classes: {n_classes}")
print(f"Class Order: {idx2name}")
print(f"Training samples  : {train_generator.samples}")
print(f"Validation samples: {val_generator.samples}")
print(f"Test samples      : {test_generator.samples}")
print("="*60)

# Save classes.json
with open(EXPERIMENT_DIR / 'classes.json', 'w') as f:
    json.dump(idx2name, f, indent=2)

print(f"\n✅ Class order saved to: {EXPERIMENT_DIR / 'classes.json'}")
# Out:
# Found 3200 images belonging to 8 classes.
# Found 400 images belonging to 8 classes.
# Found 400 images belonging to 8 classes.
#
# ============================================================
# 📚 DATA GENERATORS CREATED (Paper-Style)
# ============================================================
# Preprocessing  : rescale=1/255 (same for all models)
# Augmentation   : rotation, shift, zoom, flip, brightness
# Number of Classes: 8
# Class Order: ['Anthracnose', 'Bacterial Canker', 'Cutting Weevil', 'Die Back', 'Gall Midge', 'Healthy', 'Powdery Mildew', 'Sooty Mould']
# Training samples  : 3200
# Validation samples: 400
# Test samples      : 400
# ============================================================
#
# ✅ Class order saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/classes.json

# %% [markdown]
# ## 3. Model Architecture
#
# ### Build VGG16 Baseline Model

# %%
# ============================================
# VGG16 BASELINE MODEL (Transfer Learning)
# ============================================
# Paper-style: frozen base + simple classification head

print("\n" + "="*60)
print(f"🏗️  BUILDING {MODEL_NAME} BASELINE MODEL (Paper-style)")
print("="*60)

# 1) Load base model with ImageNet weights
base_model = VGG16(weights="imagenet", include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))

# 2) Freeze ALL base layers (no fine-tuning for baseline)
base_model.trainable = False

print(f"✅ Base model loaded with ImageNet weights")
print(f"   • Base model layers frozen: {len(base_model.layers)} layers")

# 3) Simple classification head (paper-style)
inputs = Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D(name='gap')(x)
x = Dense(512, activation='relu', name='fc1')(x)
x = Dropout(DROPOUT_RATE, name='dropout')(x)
outputs = Dense(n_classes, activation='softmax', name='output')(x)

# 4) Create model
model = Model(inputs, outputs, name=f'{MODEL_NAME}_baseline')

print(f"\n✅ Baseline model built successfully!")
print(f"   • Model: {MODEL_NAME}")
print(f"   • Input Shape: {IMG_SIZE}×{IMG_SIZE}×3")
print(f"   • Number of Classes: {n_classes}")
print(f"   • Head: GAP → Dense(512) → Dropout({DROPOUT_RATE}) → Output")

model.summary()
# Out:
# ============================================================
# 🏗️  BUILDING VGG16 BASELINE MODEL (Paper-style)
# ============================================================
# ✅ Base model loaded with ImageNet weights
#    • Base model layers frozen: 19 layers
#
# ✅ Baseline model built successfully!
#    • Model: VGG16
#    • Input Shape: 227×227×3
#    • Number of Classes: 8
#    • Head: GAP → Dense(512) → Dropout(0.3) → Output
# Model: "VGG16_baseline"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  gap (GlobalAveragePooling2  (None, 512)               0
#  D)
#
#  fc1 (Dense)                 (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  output (Dense)              (None, 8)                 4104
#
# =================================================================
# Total params: 14981448 (57.15 MB)
# Trainable params: 266760 (1.02 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## 4. Model Training
#
# ### Compile and Train (Paper-Style)

# %%
# ============================================
# COMPILE MODEL (Paper-Style)
# ============================================
# SGD with momentum=0.9, no Nesterov (matching paper)

optimizer = SGD(learning_rate=LEARNING_RATE, momentum=0.9, nesterov=False)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("✅ Model compiled (Paper-style)")
print(f"   • Optimizer: SGD (momentum=0.9, no Nesterov)")
print(f"   • Learning Rate: {LEARNING_RATE} (fixed)")
print(f"   • Loss: Categorical Crossentropy")
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# ✅ Model compiled (Paper-style)
#    • Optimizer: SGD (momentum=0.9, no Nesterov)
#    • Learning Rate: 0.001 (fixed)
#    • Loss: Categorical Crossentropy

# %%
# ============================================
# MINIMAL CALLBACKS (Paper-Style)
# ============================================
# No EarlyStopping, no ReduceLROnPlateau
# Just checkpoint best model and log training

model_filename = f"{MODEL_NAME}_{DATASET_NAME}_best.h5"
model_path = EXPERIMENT_DIR / model_filename
csv_log_path = EXPERIMENT_DIR / 'training_log.csv'

callbacks = [
    ModelCheckpoint(
        filepath=str(model_path),
        monitor='val_accuracy',
        mode='max',
        save_best_only=True,
        save_weights_only=False,
        verbose=1
    ),
    CSVLogger(
        filename=str(csv_log_path),
        append=False
    )
]

print("="*60)
print("🔧 MINIMAL CALLBACKS (Paper-Style)")
print("="*60)
print(f"ModelCheckpoint: Save best model to {model_filename}")
print(f"CSVLogger: Log to {csv_log_path.name}")
print("NO EarlyStopping (train for full {EPOCHS} epochs)")
print("NO ReduceLROnPlateau (fixed learning rate)")
print("="*60)

# Save model info
total_params = model.count_params()
trainable_params = sum([tf.size(w).numpy() for w in model.trainable_weights])

model_info = {
    'dataset': DATASET_NAME,
    'model_name': MODEL_NAME,
    'architecture': 'Transfer Learning Baseline',
    'paper_style': True,
    'input_shape': [IMG_SIZE, IMG_SIZE, 3],
    'num_classes': n_classes,
    'total_params': int(total_params),
    'trainable_params': int(trainable_params),
    'batch_size': BATCH_SIZE,
    'epochs': EPOCHS,
    'learning_rate': LEARNING_RATE,
    'optimizer': 'SGD (momentum=0.9)',
    'model_path': str(model_path)
}

with open(EXPERIMENT_DIR / 'model_info.json', 'w') as f:
    json.dump(model_info, f, indent=2)

print(f"\n✅ Model info saved to: {EXPERIMENT_DIR / 'model_info.json'}")
# Out:
# ============================================================
# 🔧 MINIMAL CALLBACKS (Paper-Style)
# ============================================================
# ModelCheckpoint: Save best model to VGG16_MangoLeafBD_best.h5
# CSVLogger: Log to training_log.csv
# NO EarlyStopping (train for full {EPOCHS} epochs)
# NO ReduceLROnPlateau (fixed learning rate)
# ============================================================
#
# ✅ Model info saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/model_info.json

# %%
# ============================================
# TRAINING (Paper-Style: Fixed Epochs)
# ============================================

print("\n" + "="*80)
print("🚀 STARTING TRAINING (Paper-Style Baseline)")
print("="*80)
print(f"Model: {MODEL_NAME}")
print(f"Dataset: {DATASET_NAME}")
print(f"Epochs: {EPOCHS} (fixed, no early stopping)")
print(f"Batch Size: {BATCH_SIZE}")
print(f"Learning Rate: {LEARNING_RATE} (fixed, no decay)")
print("="*80 + "\n")

start_time = time.time()

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

end_time = time.time()
training_time = end_time - start_time

print("\n" + "="*80)
print("✅ TRAINING COMPLETED")
print("="*80)
print(f"Total training time: {training_time/60:.2f} minutes")
print(f"Best model saved to: {model_path}")
print("="*80)

# Save training history
history_dict = {k: [float(x) for x in v] for k, v in history.history.items()}
with open(EXPERIMENT_DIR / 'history.json', 'w') as f:
    json.dump(history_dict, f, indent=2)

print(f"\n✅ Training history saved to: {EXPERIMENT_DIR / 'history.json'}")
# Out:
# ================================================================================
# 🚀 STARTING TRAINING (Paper-Style Baseline)
# ================================================================================
# Model: VGG16
# Dataset: MangoLeafBD
# Epochs: 100 (fixed, no early stopping)
# Batch Size: 12
# Learning Rate: 0.001 (fixed, no decay)
# ================================================================================
#
# Epoch 1/100
# 2025-11-27 06:02:14.449442: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node SGD/AssignVariableOp.
# 267/267 [==============================] - ETA: 0s - loss: 1.9322 - accuracy: 0.2788
# Epoch 1: val_accuracy improved from -inf to 0.40500, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 30s 108ms/step - loss: 1.9322 - accuracy: 0.2788 - val_loss: 1.6768 - val_accuracy: 0.4050
# Epoch 2/100
# 267/267 [==============================] - ETA: 0s - loss: 1.5358 - accuracy: 0.4900
# Epoch 2: val_accuracy improved from 0.40500 to 0.43750, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 30s 111ms/step - loss: 1.5358 - accuracy: 0.4900 - val_loss: 1.5464 - val_accuracy: 0.4375
# Epoch 3/100
# 267/267 [==============================] - ETA: 0s - loss: 1.2978 - accuracy: 0.6056
# Epoch 3: val_accuracy improved from 0.43750 to 0.67500, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 30s 113ms/step - loss: 1.2978 - accuracy: 0.6056 - val_loss: 1.2261 - val_accuracy: 0.6750
# Epoch 4/100
# 267/267 [==============================] - ETA: 0s - loss: 1.1127 - accuracy: 0.6731
# Epoch 4: val_accuracy improved from 0.67500 to 0.68250, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 33s 122ms/step - loss: 1.1127 - accuracy: 0.6731 - val_loss: 1.0623 - val_accuracy: 0.6825
# Epoch 5/100
# 267/267 [==============================] - ETA: 0s - loss: 0.9904 - accuracy: 0.7113
# Epoch 5: val_accuracy did not improve from 0.68250
# 267/267 [==============================] - 46s 173ms/step - loss: 0.9904 - accuracy: 0.7113 - val_loss: 1.0074 - val_accuracy: 0.6675
# Epoch 6/100
# 267/267 [==============================] - ETA: 0s - loss: 0.8811 - accuracy: 0.7541
# Epoch 6: val_accuracy improved from 0.68250 to 0.79500, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 52s 195ms/step - loss: 0.8811 - accuracy: 0.7541 - val_loss: 0.8672 - val_accuracy: 0.7950
# Epoch 7/100
# 267/267 [==============================] - ETA: 0s - loss: 0.7879 - accuracy: 0.7894
# Epoch 7: val_accuracy improved from 0.79500 to 0.80000, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 98s 368ms/step - loss: 0.7879 - accuracy: 0.7894 - val_loss: 0.7962 - val_accuracy: 0.8000
# Epoch 8/100
# 267/267 [==============================] - ETA: 0s - loss: 0.7190 - accuracy: 0.7959
# Epoch 8: val_accuracy did not improve from 0.80000
# 267/267 [==============================] - 97s 364ms/step - loss: 0.7190 - accuracy: 0.7959 - val_loss: 0.7971 - val_accuracy: 0.7650
# Epoch 9/100
# 267/267 [==============================] - ETA: 0s - loss: 0.6713 - accuracy: 0.8094
# Epoch 9: val_accuracy improved from 0.80000 to 0.80250, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 98s 368ms/step - loss: 0.6713 - accuracy: 0.8094 - val_loss: 0.7027 - val_accuracy: 0.8025
# Epoch 10/100
# 267/267 [==============================] - ETA: 0s - loss: 0.6299 - accuracy: 0.8128
# Epoch 10: val_accuracy improved from 0.80250 to 0.82500, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 98s 369ms/step - loss: 0.6299 - accuracy: 0.8128 - val_loss: 0.6605 - val_accuracy: 0.8250
# Epoch 11/100
# 267/267 [==============================] - ETA: 0s - loss: 0.5734 - accuracy: 0.8369
# Epoch 11: val_accuracy did not improve from 0.82500
# 267/267 [==============================] - 96s 360ms/step - loss: 0.5734 - accuracy: 0.8369 - val_loss: 0.6859 - val_accuracy: 0.7925
# Epoch 12/100
# 267/267 [==============================] - ETA: 0s - loss: 0.5374 - accuracy: 0.8469
# Epoch 12: val_accuracy improved from 0.82500 to 0.83250, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 98s 365ms/step - loss: 0.5374 - accuracy: 0.8469 - val_loss: 0.6049 - val_accuracy: 0.8325
# Epoch 13/100
# 267/267 [==============================] - ETA: 0s - loss: 0.5165 - accuracy: 0.8481
# Epoch 13: val_accuracy improved from 0.83250 to 0.84250, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 98s 367ms/step - loss: 0.5165 - accuracy: 0.8481 - val_loss: 0.5468 - val_accuracy: 0.8425
# Epoch 14/100
# 267/267 [==============================] - ETA: 0s - loss: 0.4669 - accuracy: 0.8653
# Epoch 14: val_accuracy improved from 0.84250 to 0.85250, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 96s 360ms/step - loss: 0.4669 - accuracy: 0.8653 - val_loss: 0.5244 - val_accuracy: 0.8525
# Epoch 15/100
# 267/267 [==============================] - ETA: 0s - loss: 0.4678 - accuracy: 0.8603
# Epoch 15: val_accuracy improved from 0.85250 to 0.86750, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 96s 360ms/step - loss: 0.4678 - accuracy: 0.8603 - val_loss: 0.4645 - val_accuracy: 0.8675
# Epoch 16/100
# 267/267 [==============================] - ETA: 0s - loss: 0.4382 - accuracy: 0.8781
# Epoch 16: val_accuracy improved from 0.86750 to 0.88500, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 98s 366ms/step - loss: 0.4382 - accuracy: 0.8781 - val_loss: 0.4382 - val_accuracy: 0.8850
# Epoch 17/100
# 267/267 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.8803
# Epoch 17: val_accuracy did not improve from 0.88500
# 267/267 [==============================] - 97s 363ms/step - loss: 0.4132 - accuracy: 0.8803 - val_loss: 0.4816 - val_accuracy: 0.8600
# Epoch 18/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.8847
# Epoch 18: val_accuracy did not improve from 0.88500
# 267/267 [==============================] - 96s 359ms/step - loss: 0.3957 - accuracy: 0.8847 - val_loss: 0.3945 - val_accuracy: 0.8775
# Epoch 19/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3838 - accuracy: 0.8884
# Epoch 19: val_accuracy did not improve from 0.88500
# 267/267 [==============================] - 96s 359ms/step - loss: 0.3838 - accuracy: 0.8884 - val_loss: 0.4213 - val_accuracy: 0.8750
# Epoch 20/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3772 - accuracy: 0.8834
# Epoch 20: val_accuracy did not improve from 0.88500
# 267/267 [==============================] - 96s 361ms/step - loss: 0.3772 - accuracy: 0.8834 - val_loss: 0.3984 - val_accuracy: 0.8775
# Epoch 21/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.8913
# Epoch 21: val_accuracy improved from 0.88500 to 0.90000, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 96s 361ms/step - loss: 0.3528 - accuracy: 0.8913 - val_loss: 0.3343 - val_accuracy: 0.9000
# Epoch 22/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3491 - accuracy: 0.8988
# Epoch 22: val_accuracy improved from 0.90000 to 0.90750, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 96s 361ms/step - loss: 0.3491 - accuracy: 0.8988 - val_loss: 0.3484 - val_accuracy: 0.9075
# Epoch 23/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.9003
# Epoch 23: val_accuracy improved from 0.90750 to 0.92000, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 97s 363ms/step - loss: 0.3369 - accuracy: 0.9003 - val_loss: 0.3260 - val_accuracy: 0.9200
# Epoch 24/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3240 - accuracy: 0.9009
# Epoch 24: val_accuracy did not improve from 0.92000
# 267/267 [==============================] - 96s 361ms/step - loss: 0.3240 - accuracy: 0.9009 - val_loss: 0.3518 - val_accuracy: 0.8975
# Epoch 25/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3169 - accuracy: 0.9062
# Epoch 25: val_accuracy did not improve from 0.92000
# 267/267 [==============================] - 97s 363ms/step - loss: 0.3169 - accuracy: 0.9062 - val_loss: 0.3143 - val_accuracy: 0.9125
# Epoch 26/100
# 267/267 [==============================] - ETA: 0s - loss: 0.3068 - accuracy: 0.9047
# Epoch 26: val_accuracy did not improve from 0.92000
# 267/267 [==============================] - 97s 364ms/step - loss: 0.3068 - accuracy: 0.9047 - val_loss: 0.3033 - val_accuracy: 0.9150
# Epoch 27/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2913 - accuracy: 0.9150
# Epoch 27: val_accuracy did not improve from 0.92000
# 267/267 [==============================] - 97s 363ms/step - loss: 0.2913 - accuracy: 0.9150 - val_loss: 0.3364 - val_accuracy: 0.9100
# Epoch 28/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2912 - accuracy: 0.9181
# Epoch 28: val_accuracy improved from 0.92000 to 0.93250, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 97s 362ms/step - loss: 0.2912 - accuracy: 0.9181 - val_loss: 0.2791 - val_accuracy: 0.9325
# Epoch 29/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2821 - accuracy: 0.9147
# Epoch 29: val_accuracy did not improve from 0.93250
# 267/267 [==============================] - 97s 362ms/step - loss: 0.2821 - accuracy: 0.9147 - val_loss: 0.3202 - val_accuracy: 0.9100
# Epoch 30/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2848 - accuracy: 0.9084
# Epoch 30: val_accuracy did not improve from 0.93250
# 267/267 [==============================] - 96s 361ms/step - loss: 0.2848 - accuracy: 0.9084 - val_loss: 0.3301 - val_accuracy: 0.8975
# Epoch 31/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2643 - accuracy: 0.9197
# Epoch 31: val_accuracy did not improve from 0.93250
# 267/267 [==============================] - 97s 365ms/step - loss: 0.2643 - accuracy: 0.9197 - val_loss: 0.2523 - val_accuracy: 0.9300
# Epoch 32/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.9216
# Epoch 32: val_accuracy did not improve from 0.93250
# 267/267 [==============================] - 96s 360ms/step - loss: 0.2667 - accuracy: 0.9216 - val_loss: 0.2555 - val_accuracy: 0.9175
# Epoch 33/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2566 - accuracy: 0.9253
# Epoch 33: val_accuracy did not improve from 0.93250
# 267/267 [==============================] - 96s 361ms/step - loss: 0.2566 - accuracy: 0.9253 - val_loss: 0.2804 - val_accuracy: 0.9225
# Epoch 34/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.9184
# Epoch 34: val_accuracy did not improve from 0.93250
# 267/267 [==============================] - 97s 364ms/step - loss: 0.2611 - accuracy: 0.9184 - val_loss: 0.2666 - val_accuracy: 0.9150
# Epoch 35/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2414 - accuracy: 0.9272
# Epoch 35: val_accuracy did not improve from 0.93250
# 267/267 [==============================] - 96s 359ms/step - loss: 0.2414 - accuracy: 0.9272 - val_loss: 0.3134 - val_accuracy: 0.9125
# Epoch 36/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2508 - accuracy: 0.9181
# Epoch 36: val_accuracy improved from 0.93250 to 0.93750, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 96s 361ms/step - loss: 0.2508 - accuracy: 0.9181 - val_loss: 0.2596 - val_accuracy: 0.9375
# Epoch 37/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2459 - accuracy: 0.9222
# Epoch 37: val_accuracy did not improve from 0.93750
# 267/267 [==============================] - 96s 361ms/step - loss: 0.2459 - accuracy: 0.9222 - val_loss: 0.2667 - val_accuracy: 0.9225
# Epoch 38/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2451 - accuracy: 0.9234
# Epoch 38: val_accuracy did not improve from 0.93750
# 267/267 [==============================] - 96s 357ms/step - loss: 0.2451 - accuracy: 0.9234 - val_loss: 0.2713 - val_accuracy: 0.9225
# Epoch 39/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2313 - accuracy: 0.9269
# Epoch 39: val_accuracy did not improve from 0.93750
# 267/267 [==============================] - 96s 359ms/step - loss: 0.2313 - accuracy: 0.9269 - val_loss: 0.2321 - val_accuracy: 0.9375
# Epoch 40/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9266
# Epoch 40: val_accuracy did not improve from 0.93750
# 267/267 [==============================] - 96s 360ms/step - loss: 0.2308 - accuracy: 0.9266 - val_loss: 0.2861 - val_accuracy: 0.9175
# Epoch 41/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2381 - accuracy: 0.9234
# Epoch 41: val_accuracy did not improve from 0.93750
# 267/267 [==============================] - 96s 361ms/step - loss: 0.2381 - accuracy: 0.9234 - val_loss: 0.3247 - val_accuracy: 0.9025
# Epoch 42/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9306
# Epoch 42: val_accuracy did not improve from 0.93750
# 267/267 [==============================] - 98s 365ms/step - loss: 0.2241 - accuracy: 0.9306 - val_loss: 0.2503 - val_accuracy: 0.9250
# Epoch 43/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2185 - accuracy: 0.9328
# Epoch 43: val_accuracy did not improve from 0.93750
# 267/267 [==============================] - 97s 363ms/step - loss: 0.2185 - accuracy: 0.9328 - val_loss: 0.2556 - val_accuracy: 0.9350
# Epoch 44/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2212 - accuracy: 0.9312
# Epoch 44: val_accuracy did not improve from 0.93750
# 267/267 [==============================] - 97s 362ms/step - loss: 0.2212 - accuracy: 0.9312 - val_loss: 0.2777 - val_accuracy: 0.9150
# Epoch 45/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2213 - accuracy: 0.9303
# Epoch 45: val_accuracy did not improve from 0.93750
# 267/267 [==============================] - 96s 361ms/step - loss: 0.2213 - accuracy: 0.9303 - val_loss: 0.3859 - val_accuracy: 0.8775
# Epoch 46/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9366
# Epoch 46: val_accuracy did not improve from 0.93750
# 267/267 [==============================] - 96s 358ms/step - loss: 0.2109 - accuracy: 0.9366 - val_loss: 0.2081 - val_accuracy: 0.9300
# Epoch 47/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9341
# Epoch 47: val_accuracy did not improve from 0.93750
# 267/267 [==============================] - 96s 361ms/step - loss: 0.2109 - accuracy: 0.9341 - val_loss: 0.2128 - val_accuracy: 0.9325
# Epoch 48/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2107 - accuracy: 0.9344
# Epoch 48: val_accuracy improved from 0.93750 to 0.94000, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 97s 361ms/step - loss: 0.2107 - accuracy: 0.9344 - val_loss: 0.2290 - val_accuracy: 0.9400
# Epoch 49/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2096 - accuracy: 0.9300
# Epoch 49: val_accuracy did not improve from 0.94000
# 267/267 [==============================] - 97s 362ms/step - loss: 0.2096 - accuracy: 0.9300 - val_loss: 0.2234 - val_accuracy: 0.9300
# Epoch 50/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2027 - accuracy: 0.9366
# Epoch 50: val_accuracy improved from 0.94000 to 0.95250, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 97s 363ms/step - loss: 0.2027 - accuracy: 0.9366 - val_loss: 0.1624 - val_accuracy: 0.9525
# Epoch 51/100
# 267/267 [==============================] - ETA: 0s - loss: 0.2035 - accuracy: 0.9331
# Epoch 51: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 97s 363ms/step - loss: 0.2035 - accuracy: 0.9331 - val_loss: 0.2530 - val_accuracy: 0.9200
# Epoch 52/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9334
# Epoch 52: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 369ms/step - loss: 0.1980 - accuracy: 0.9334 - val_loss: 0.2180 - val_accuracy: 0.9400
# Epoch 53/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9381
# Epoch 53: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 366ms/step - loss: 0.1892 - accuracy: 0.9381 - val_loss: 0.1851 - val_accuracy: 0.9375
# Epoch 54/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1968 - accuracy: 0.9369
# Epoch 54: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 368ms/step - loss: 0.1968 - accuracy: 0.9369 - val_loss: 0.1661 - val_accuracy: 0.9400
# Epoch 55/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1894 - accuracy: 0.9397
# Epoch 55: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 367ms/step - loss: 0.1894 - accuracy: 0.9397 - val_loss: 0.2298 - val_accuracy: 0.9350
# Epoch 56/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1810 - accuracy: 0.9419
# Epoch 56: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 365ms/step - loss: 0.1810 - accuracy: 0.9419 - val_loss: 0.1838 - val_accuracy: 0.9425
# Epoch 57/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1762 - accuracy: 0.9447
# Epoch 57: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 367ms/step - loss: 0.1762 - accuracy: 0.9447 - val_loss: 0.1801 - val_accuracy: 0.9425
# Epoch 58/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1768 - accuracy: 0.9425
# Epoch 58: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 367ms/step - loss: 0.1768 - accuracy: 0.9425 - val_loss: 0.1873 - val_accuracy: 0.9450
# Epoch 59/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1776 - accuracy: 0.9475
# Epoch 59: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 368ms/step - loss: 0.1776 - accuracy: 0.9475 - val_loss: 0.2193 - val_accuracy: 0.9300
# Epoch 60/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9438
# Epoch 60: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 368ms/step - loss: 0.1693 - accuracy: 0.9438 - val_loss: 0.2015 - val_accuracy: 0.9375
# Epoch 61/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1760 - accuracy: 0.9434
# Epoch 61: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 369ms/step - loss: 0.1760 - accuracy: 0.9434 - val_loss: 0.1762 - val_accuracy: 0.9425
# Epoch 62/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1764 - accuracy: 0.9450
# Epoch 62: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 99s 369ms/step - loss: 0.1764 - accuracy: 0.9450 - val_loss: 0.1752 - val_accuracy: 0.9450
# Epoch 63/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1744 - accuracy: 0.9438
# Epoch 63: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 99s 371ms/step - loss: 0.1744 - accuracy: 0.9438 - val_loss: 0.1779 - val_accuracy: 0.9400
# Epoch 64/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1573 - accuracy: 0.9513
# Epoch 64: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 367ms/step - loss: 0.1573 - accuracy: 0.9513 - val_loss: 0.1677 - val_accuracy: 0.9425
# Epoch 65/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1767 - accuracy: 0.9469
# Epoch 65: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 368ms/step - loss: 0.1767 - accuracy: 0.9469 - val_loss: 0.1829 - val_accuracy: 0.9375
# Epoch 66/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1735 - accuracy: 0.9422
# Epoch 66: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 369ms/step - loss: 0.1735 - accuracy: 0.9422 - val_loss: 0.2090 - val_accuracy: 0.9300
# Epoch 67/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1807 - accuracy: 0.9434
# Epoch 67: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 366ms/step - loss: 0.1807 - accuracy: 0.9434 - val_loss: 0.1917 - val_accuracy: 0.9350
# Epoch 68/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1630 - accuracy: 0.9463
# Epoch 68: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 367ms/step - loss: 0.1630 - accuracy: 0.9463 - val_loss: 0.2007 - val_accuracy: 0.9425
# Epoch 69/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 0.9503
# Epoch 69: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 366ms/step - loss: 0.1632 - accuracy: 0.9503 - val_loss: 0.1651 - val_accuracy: 0.9475
# Epoch 70/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9494
# Epoch 70: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 97s 364ms/step - loss: 0.1606 - accuracy: 0.9494 - val_loss: 0.1696 - val_accuracy: 0.9475
# Epoch 71/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.9491
# Epoch 71: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 366ms/step - loss: 0.1645 - accuracy: 0.9491 - val_loss: 0.1592 - val_accuracy: 0.9525
# Epoch 72/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1621 - accuracy: 0.9500
# Epoch 72: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 97s 364ms/step - loss: 0.1621 - accuracy: 0.9500 - val_loss: 0.1717 - val_accuracy: 0.9500
# Epoch 73/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1505 - accuracy: 0.9531
# Epoch 73: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 97s 364ms/step - loss: 0.1505 - accuracy: 0.9531 - val_loss: 0.1838 - val_accuracy: 0.9425
# Epoch 74/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1622 - accuracy: 0.9441
# Epoch 74: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 365ms/step - loss: 0.1622 - accuracy: 0.9441 - val_loss: 0.1685 - val_accuracy: 0.9475
# Epoch 75/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1494 - accuracy: 0.9525
# Epoch 75: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 366ms/step - loss: 0.1494 - accuracy: 0.9525 - val_loss: 0.2359 - val_accuracy: 0.9275
# Epoch 76/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1574 - accuracy: 0.9491
# Epoch 76: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 365ms/step - loss: 0.1574 - accuracy: 0.9491 - val_loss: 0.2026 - val_accuracy: 0.9225
# Epoch 77/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9450
# Epoch 77: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 97s 363ms/step - loss: 0.1623 - accuracy: 0.9450 - val_loss: 0.1770 - val_accuracy: 0.9425
# Epoch 78/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9488
# Epoch 78: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 97s 364ms/step - loss: 0.1551 - accuracy: 0.9488 - val_loss: 0.1458 - val_accuracy: 0.9525
# Epoch 79/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1620 - accuracy: 0.9434
# Epoch 79: val_accuracy did not improve from 0.95250
# 267/267 [==============================] - 98s 365ms/step - loss: 0.1620 - accuracy: 0.9434 - val_loss: 0.1904 - val_accuracy: 0.9400
# Epoch 80/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1501 - accuracy: 0.9475
# Epoch 80: val_accuracy improved from 0.95250 to 0.96000, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 98s 368ms/step - loss: 0.1501 - accuracy: 0.9475 - val_loss: 0.1402 - val_accuracy: 0.9600
# Epoch 81/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1610 - accuracy: 0.9450
# Epoch 81: val_accuracy did not improve from 0.96000
# 267/267 [==============================] - 97s 362ms/step - loss: 0.1610 - accuracy: 0.9450 - val_loss: 0.1820 - val_accuracy: 0.9450
# Epoch 82/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 0.9506
# Epoch 82: val_accuracy did not improve from 0.96000
# 267/267 [==============================] - 97s 365ms/step - loss: 0.1488 - accuracy: 0.9506 - val_loss: 0.1353 - val_accuracy: 0.9550
# Epoch 83/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9559
# Epoch 83: val_accuracy did not improve from 0.96000
# 267/267 [==============================] - 96s 359ms/step - loss: 0.1415 - accuracy: 0.9559 - val_loss: 0.1288 - val_accuracy: 0.9475
# Epoch 84/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1491 - accuracy: 0.9494
# Epoch 84: val_accuracy did not improve from 0.96000
# 267/267 [==============================] - 70s 263ms/step - loss: 0.1491 - accuracy: 0.9494 - val_loss: 0.2208 - val_accuracy: 0.9325
# Epoch 85/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9556
# Epoch 85: val_accuracy did not improve from 0.96000
# 267/267 [==============================] - 69s 259ms/step - loss: 0.1431 - accuracy: 0.9556 - val_loss: 0.1457 - val_accuracy: 0.9450
# Epoch 86/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1313 - accuracy: 0.9566
# Epoch 86: val_accuracy did not improve from 0.96000
# 267/267 [==============================] - 69s 258ms/step - loss: 0.1313 - accuracy: 0.9566 - val_loss: 0.1426 - val_accuracy: 0.9525
# Epoch 87/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1448 - accuracy: 0.9500
# Epoch 87: val_accuracy did not improve from 0.96000
# 267/267 [==============================] - 69s 259ms/step - loss: 0.1448 - accuracy: 0.9500 - val_loss: 0.1888 - val_accuracy: 0.9400
# Epoch 88/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1376 - accuracy: 0.9550
# Epoch 88: val_accuracy did not improve from 0.96000
# 267/267 [==============================] - 69s 259ms/step - loss: 0.1376 - accuracy: 0.9550 - val_loss: 0.1195 - val_accuracy: 0.9550
# Epoch 89/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9513
# Epoch 89: val_accuracy did not improve from 0.96000
# 267/267 [==============================] - 69s 260ms/step - loss: 0.1420 - accuracy: 0.9513 - val_loss: 0.1225 - val_accuracy: 0.9550
# Epoch 90/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1534 - accuracy: 0.9497
# Epoch 90: val_accuracy did not improve from 0.96000
# 267/267 [==============================] - 69s 260ms/step - loss: 0.1534 - accuracy: 0.9497 - val_loss: 0.1890 - val_accuracy: 0.9500
# Epoch 91/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1354 - accuracy: 0.9578
# Epoch 91: val_accuracy did not improve from 0.96000
# 267/267 [==============================] - 70s 261ms/step - loss: 0.1354 - accuracy: 0.9578 - val_loss: 0.1219 - val_accuracy: 0.9550
# Epoch 92/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9544
# Epoch 92: val_accuracy improved from 0.96000 to 0.96500, saving model to /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# 267/267 [==============================] - 70s 261ms/step - loss: 0.1386 - accuracy: 0.9544 - val_loss: 0.1188 - val_accuracy: 0.9650
# Epoch 93/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1341 - accuracy: 0.9550
# Epoch 93: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 70s 261ms/step - loss: 0.1341 - accuracy: 0.9550 - val_loss: 0.1631 - val_accuracy: 0.9525
# Epoch 94/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9547
# Epoch 94: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 70s 261ms/step - loss: 0.1361 - accuracy: 0.9547 - val_loss: 0.1780 - val_accuracy: 0.9425
# Epoch 95/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9525
# Epoch 95: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 69s 259ms/step - loss: 0.1485 - accuracy: 0.9525 - val_loss: 0.1214 - val_accuracy: 0.9600
# Epoch 96/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9531
# Epoch 96: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 69s 258ms/step - loss: 0.1397 - accuracy: 0.9531 - val_loss: 0.1333 - val_accuracy: 0.9525
# Epoch 97/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9538
# Epoch 97: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 70s 263ms/step - loss: 0.1372 - accuracy: 0.9538 - val_loss: 0.2282 - val_accuracy: 0.9250
# Epoch 98/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9456
# Epoch 98: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 70s 260ms/step - loss: 0.1490 - accuracy: 0.9456 - val_loss: 0.2079 - val_accuracy: 0.9225
# Epoch 99/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1326 - accuracy: 0.9566
# Epoch 99: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 70s 262ms/step - loss: 0.1326 - accuracy: 0.9566 - val_loss: 0.1413 - val_accuracy: 0.9500
# Epoch 100/100
# 267/267 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9463
# Epoch 100: val_accuracy did not improve from 0.96500
# 267/267 [==============================] - 70s 262ms/step - loss: 0.1411 - accuracy: 0.9463 - val_loss: 0.1773 - val_accuracy: 0.9400
#
# ================================================================================
# ✅ TRAINING COMPLETED
# ================================================================================
# Total training time: 148.12 minutes
# Best model saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# ================================================================================
#
# ✅ Training history saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/history.json

# %% [markdown]
# ## 5. Model Evaluation
#
# ### Load Best Model and Generate Predictions

# %%
# ============================================
# MODEL EVALUATION
# ============================================

print("="*60)
print("📥 LOADING BEST MODEL FOR EVALUATION")
print("="*60)
print(f"Model path: {model_path}")

best_model = load_model(str(model_path))
print("✅ Best model loaded successfully!")

# Make predictions
print("\n🔮 Making predictions on test set...")
y_pred_probs = best_model.predict(test_generator, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes

# Calculate metrics
overall_accuracy = accuracy_score(y_true, y_pred)
macro_precision, macro_recall, macro_f1, _ = precision_recall_fscore_support(
    y_true, y_pred, average='macro'
)
weighted_precision, weighted_recall, weighted_f1, _ = precision_recall_fscore_support(
    y_true, y_pred, average='weighted'
)

# Classification report
report = classification_report(
    y_true, y_pred,
    target_names=idx2name,
    digits=4
)

print("\n" + "="*80)
print("📊 EVALUATION RESULTS")
print("="*80)
print(f"Overall Accuracy: {overall_accuracy:.4f} ({overall_accuracy*100:.2f}%)")
print(f"Macro Precision : {macro_precision:.4f}")
print(f"Macro Recall    : {macro_recall:.4f}")
print(f"Macro F1-Score  : {macro_f1:.4f}")
print("="*80)
print("\n" + report)

# Save classification report
with open(OUTPUT_DIR / 'classification_report.txt', 'w') as f:
    f.write(f"{MODEL_NAME} on {DATASET_NAME} - Classification Report\n")
    f.write("="*80 + "\n\n")
    f.write(report)

# Save metrics CSV
precision, recall, f1, support = precision_recall_fscore_support(
    y_true, y_pred, average=None, labels=range(n_classes)
)
metrics_df = pd.DataFrame({
    'Class': idx2name,
    'Precision': precision,
    'Recall': recall,
    'F1-Score': f1,
    'Support': support
})
metrics_df.to_csv(OUTPUT_DIR / 'per_class_metrics.csv', index=False)

# Save evaluation summary
summary = f"""{'='*80}
{MODEL_NAME} on {DATASET_NAME} - Evaluation Summary (Paper-Style Baseline)
{'='*80}

Model: {MODEL_NAME}
Dataset: {DATASET_NAME}
Test Accuracy: {overall_accuracy:.4f} ({overall_accuracy*100:.2f}%)
Macro Avg - P: {macro_precision:.4f}, R: {macro_recall:.4f}, F1: {macro_f1:.4f}
Weighted Avg - P: {weighted_precision:.4f}, R: {weighted_recall:.4f}, F1: {weighted_f1:.4f}

Training Settings:
- Input Size: {IMG_SIZE}×{IMG_SIZE}
- Epochs: {EPOCHS} (fixed)
- Batch Size: {BATCH_SIZE}
- Learning Rate: {LEARNING_RATE}
- Optimizer: SGD (momentum=0.9)
{'='*80}
"""

with open(OUTPUT_DIR / 'evaluation_summary.txt', 'w') as f:
    f.write(summary)

print(f"\n✅ Results saved to: {OUTPUT_DIR}")
# Out:
# ============================================================
# 📥 LOADING BEST MODEL FOR EVALUATION
# ============================================================
# Model path: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/experiments/VGG16/run_3/VGG16_MangoLeafBD_best.h5
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.SGD` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.SGD`.
# ✅ Best model loaded successfully!
#
# 🔮 Making predictions on test set...
# 34/34 [==============================] - 7s 213ms/step
#
# ================================================================================
# 📊 EVALUATION RESULTS
# ================================================================================
# Overall Accuracy: 0.9750 (97.50%)
# Macro Precision : 0.9755
# Macro Recall    : 0.9750
# Macro F1-Score  : 0.9751
# ================================================================================
#
#                   precision    recall  f1-score   support
#
#      Anthracnose     1.0000    0.9800    0.9899        50
# Bacterial Canker     0.9800    0.9800    0.9800        50
#   Cutting Weevil     1.0000    1.0000    1.0000        50
#         Die Back     1.0000    0.9600    0.9796        50
#       Gall Midge     0.9412    0.9600    0.9505        50
#          Healthy     0.9423    0.9800    0.9608        50
#   Powdery Mildew     0.9608    0.9800    0.9703        50
#      Sooty Mould     0.9796    0.9600    0.9697        50
#
#         accuracy                         0.9750       400
#        macro avg     0.9755    0.9750    0.9751       400
#     weighted avg     0.9755    0.9750    0.9751       400
#
#
# ✅ Results saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/outputs/VGG16/run_3

# %%
# ============================================
# VISUALIZATIONS
# ============================================

# 1) Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=idx2name,
            yticklabels=idx2name,
            cbar_kws={'label': 'Count'})
plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')
plt.ylabel('True Label', fontsize=12, fontweight='bold')
plt.title(f'Confusion Matrix - {MODEL_NAME} on {DATASET_NAME} (Paper-Style Baseline)',
         fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"✅ Confusion matrix saved to: {OUTPUT_DIR / 'confusion_matrix.png'}")

# 2) Training History
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Loss plot
axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
axes[0].set_title('Model Loss During Training', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].legend(fontsize=11)
axes[0].grid(alpha=0.3)

# Accuracy plot
axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
axes[1].set_title('Model Accuracy During Training', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].legend(fontsize=11)
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'training_history.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"✅ Training history plot saved to: {OUTPUT_DIR / 'training_history.png'}")
# Out:
# ✅ Confusion matrix saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/outputs/VGG16/run_3/confusion_matrix.png
# ✅ Training history plot saved to: /Users/invictus/Desktop/Thesis project/MangoXPPNet_Research_Notebook/MangoLeafBD/outputs/VGG16/run_3/training_history.png
